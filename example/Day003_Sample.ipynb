# %% [markdown]
# # Python 下載XML檔案與解析
#
#
# * 了解 xml 檔案格式與內容
# * 能夠利用套件存取 xml 格式的檔案

# %% [markdown]
# ## 存取 XML 的三種套件

# %%
import xml.dom.minidom 

# 存取檔案
doc = xml.dom.minidom.parse("./example/sample.xml")

# 存取我們的資訊
print(doc.getElementsByTagName("Title")[0].firstChild.nodeValue)

# 用迴圈存取我們的資訊
chapters = doc.getElementsByTagName("Chapter")    #若<Chapters></Chapters>裡面夾雜其他tag，則不會被印出來
for chapter in chapters:
    print (chapter.getAttribute('name'), chapter.firstChild.nodeValue)
# Out:
# 爬蟲馬拉松
# 01 資料來源與存取
# 02 靜態網頁爬蟲
# 03 動態網頁爬蟲
# 05 測試點二

# %%
import xml.etree.ElementTree as ET 

# 存取檔案
tree = ET.parse("./example/sample.xml") 
root = tree.getroot() #獲取根節點

# 存取我們的資訊 
print(root[0].text)  #root[1]是：<Author>Wei</Author>

# 用迴圈存取我們的資訊
chapters = root[2]   #root[2]是：<Chapters></Chapters>，包含裡面的所有tag
for chapter in chapters:
    print (chapter.attrib['name'], chapter.text)
# Out:
# 爬蟲馬拉松
# 01 資料來源與存取
# 02 靜態網頁爬蟲
# 03 動態網頁爬蟲
# 04 測試點一，我不是Chapter
# 05 測試點二

# %%
import xmltodict

# 存取檔案

with open('./example/sample.xml',encoding="UTF-8") as fd:
    doc = dict(xmltodict.parse(fd.read()))

# 存取我們的資訊
print(doc['CUPOY']['Title'])    #<CUPOY>是最外面的tag

# 用迴圈存取我們的資訊
chapters = doc['CUPOY']['Chapters']['Chapter']    #<Chapters>裡面的所有<Chapter>，不包含其他混在<Chapters>的tag
for chapter in chapters:
    print (chapter['@name'], chapter['#text'])
# Out:
# 爬蟲馬拉松
# 01 資料來源與存取
# 02 靜態網頁爬蟲
# 03 動態網頁爬蟲
# 05 測試點二

# %% [markdown]
# ## 下載檔案

# %%
# 下載檔案
import urllib.request
import zipfile

res = "http://opendata.cwb.gov.tw/govdownload?dataid=F-D0047-093&authorizationkey=rdec-key-123-45678-011121314"
urllib.request.urlretrieve(res, "./example.zip")
f = zipfile.ZipFile('./example.zip')    #讀取zip檔案
f.extractall('./data')    #解壓縮檔案，存到Data資料夾

# %%
import os

# 打開文件
dirs = os.listdir( './data' )

# 输出所有文件和文件夹
for file in dirs:
    print(file)
# Out:
# 09007_72hr_CH.xml
# 09007_72hr_EN.xml
# 09007_Week24_CH.xml
# 09007_Week24_EN.xml
# 09007_Weekday_CH.xml
# 09007_Weekday_EN.xml
# 09020_72hr_CH.xml
# 09020_72hr_EN.xml
# 09020_Week24_CH.xml
# 09020_Week24_EN.xml
# 09020_Weekday_CH.xml
# 09020_Weekday_EN.xml
# 10002_72hr_CH.xml
# 10002_72hr_EN.xml
# 10002_Week24_CH.xml
# 10002_Week24_EN.xml
# 10002_Weekday_CH.xml
# 10002_Weekday_EN.xml
# 10004_72hr_CH.xml
# 10004_72hr_EN.xml
# 10004_Week24_CH.xml
# 10004_Week24_EN.xml
# 10004_Weekday_CH.xml
# 10004_Weekday_EN.xml
# 10005_72hr_CH.xml
# 10005_72hr_EN.xml
# 10005_Week24_CH.xml
# 10005_Week24_EN.xml
# 10005_Weekday_CH.xml
# 10005_Weekday_EN.xml
# 10007_72hr_CH.xml
# 10007_72hr_EN.xml
# 10007_Week24_CH.xml
# 10007_Week24_EN.xml
# 10007_Weekday_CH.xml
# 10007_Weekday_EN.xml
# 10008_72hr_CH.xml
# 10008_72hr_EN.xml
# 10008_Week24_CH.xml
# 10008_Week24_EN.xml
# 10008_Weekday_CH.xml
# 10008_Weekday_EN.xml
# 10009_72hr_CH.xml
# 10009_72hr_EN.xml
# 10009_Week24_CH.xml
# 10009_Week24_EN.xml
# 10009_Weekday_CH.xml
# 10009_Weekday_EN.xml
# 10010_72hr_CH.xml
# 10010_72hr_EN.xml
# 10010_Week24_CH.xml
# 10010_Week24_EN.xml
# 10010_Weekday_CH.xml
# 10010_Weekday_EN.xml
# 10013_72hr_CH.xml
# 10013_72hr_EN.xml
# 10013_Week24_CH.xml
# 10013_Week24_EN.xml
# 10013_Weekday_CH.xml
# 10013_Weekday_EN.xml
# 10014_72hr_CH.xml
# 10014_72hr_EN.xml
# 10014_Week24_CH.xml
# 10014_Week24_EN.xml
# 10014_Weekday_CH.xml
# 10014_Weekday_EN.xml
# 10015_72hr_CH.xml
# 10015_72hr_EN.xml
# 10015_Week24_CH.xml
# 10015_Week24_EN.xml
# 10015_Weekday_CH.xml
# 10015_Weekday_EN.xml
# 10016_72hr_CH.xml
# 10016_72hr_EN.xml
# 10016_Week24_CH.xml
# 10016_Week24_EN.xml
# 10016_Weekday_CH.xml
# 10016_Weekday_EN.xml
# 10017_72hr_CH.xml
# 10017_72hr_EN.xml
# 10017_Week24_CH.xml
# 10017_Week24_EN.xml
# 10017_Weekday_CH.xml
# 10017_Weekday_EN.xml
# 10018_72hr_CH.xml
# 10018_72hr_EN.xml
# 10018_Week24_CH.xml
# 10018_Week24_EN.xml
# 10018_Weekday_CH.xml
# 10018_Weekday_EN.xml
# 10020_72hr_CH.xml
# 10020_72hr_EN.xml
# 10020_Week24_CH.xml
# 10020_Week24_EN.xml
# 10020_Weekday_CH.xml
# 10020_Weekday_EN.xml
# 63_72hr_CH.xml
# 63_72hr_EN.xml
# 63_Week24_CH.xml
# 63_Week24_EN.xml
# 63_Weekday_CH.xml
# 63_Weekday_EN.xml
# 64_72hr_CH.xml
# 64_72hr_EN.xml
# 64_Week24_CH.xml
# 64_Week24_EN.xml
# 64_Weekday_CH.xml
# 64_Weekday_EN.xml
# 65_72hr_CH.xml
# 65_72hr_EN.xml
# 65_Week24_CH.xml
# 65_Week24_EN.xml
# 65_Weekday_CH.xml
# 65_Weekday_EN.xml
# 66_72hr_CH.xml
# 66_72hr_EN.xml
# 66_Week24_CH.xml
# 66_Week24_EN.xml
# 66_Weekday_CH.xml
# 66_Weekday_EN.xml
# 67_72hr_CH.xml
# 67_72hr_EN.xml
# 67_Week24_CH.xml
# 67_Week24_EN.xml
# 67_Weekday_CH.xml
# 67_Weekday_EN.xml
# 68_72hr_CH.xml
# 68_72hr_EN.xml
# 68_Week24_CH.xml
# 68_Week24_EN.xml
# 68_Weekday_CH.xml
# 68_Weekday_EN.xml
# TAIWAN_72hr_CH.xml
# TAIWAN_72hr_EN.xml
# TAIWAN_Week24_CH.xml
# TAIWAN_Week24_EN.xml
# TAIWAN_Weekday_CH.xml
# TAIWAN_Weekday_EN.xml

# %% [markdown]
# ## File I/O

# %%
# 讀檔案
fh = open("./data/64_72hr_CH.xml", "r",encoding="UTF-8")
xml = fh.read()
fh.close()

print(xml)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <cwbopendata xmlns="urn:cwb:gov:tw:cwbcommon:0.1">
#   <identifier>97ad4110-2c32-4641-abe1-d6000d9bb6c9</identifier>
#   <sender>weather@cwb.gov.tw</sender>
#   <sent>2020-05-05T06:19:54+08:00</sent>
#   <status>Actual</status>
#   <scope>Public</scope>
#   <msgType>Issue</msgType>
#   <dataid>D0047-065</dataid>
#   <source>MFC</source>
#   <dataset>
#     <datasetInfo>
#       <datasetDescription>臺灣各縣市鄉鎮未來3天(72小時)逐3小時天氣預報</datasetDescription>
#       <datasetLanguage>zh-TW</datasetLanguage>
#       <issueTime>2020-05-05T05:00:00+08:00</issueTime>
#       <validTime>
#         <startTime>2020-05-05T06:00:00+08:00</startTime>
#         <endTime>2020-05-08T05:00:00+08:00</endTime>
#       </validTime>
#       <update>2020-05-05T06:19:54+08:00</update>
#     </datasetInfo>
#     <locations>
#       <locationsName>高雄市</locationsName>
#       <location>
#         <locationName>鹽埕區</locationName>
#         <geocode>6400100</geocode>
#         <lat>22.626497</lat>
#         <lon>120.278707</lon>
#         <weatherElement>
#           <elementName>T</elementName>
#           <description>溫度</description>
#           <time>
#             <dataTime>2020-05-05T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>27</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>29</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>31</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>31</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>30</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>29</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>27</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>27</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>30</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>31</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>31</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>30</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>29</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>27</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>27</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>30</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>32</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>31</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>30</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>29</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-08T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-08T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#         </weatherElement>
#         <weatherElement>
#           <elementName>Td</elementName>
#           <description>露點溫度</description>
#           <time>
#             <dataTime>2020-05-05T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>24</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>25</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>24</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>25</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>26</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>25</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>26</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>26</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>25</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>25</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>25</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>26</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>26</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>26</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>25</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>26</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>24</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>25</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>26</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>27</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-08T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>26</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-08T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>26</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#         </weatherElement>
#         <weatherElement>
#           <elementName>RH</elementName>
#           <description>相對濕度</description>
#           <time>
#             <dataTime>2020-05-05T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>88</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>76</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>68</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>72</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>78</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>82</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>86</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>90</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>89</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>77</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>71</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>75</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>81</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>84</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>84</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>90</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>86</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>76</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>75</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>80</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>88</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>90</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-08T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>88</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-08T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>89</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#         </weatherElement>
#         <weatherElement>
#           <elementName>PoP6h</elementName>
#           <description>6小時降雨機率</description>
#           <time>
#             <startTime>2020-05-05T06:00:00+08:00</startTime>
#             <endTime>2020-05-05T12:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-05T12:00:00+08:00</startTime>
#             <endTime>2020-05-05T18:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-05T18:00:00+08:00</startTime>
#             <endTime>2020-05-06T00:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T00:00:00+08:00</startTime>
#             <endTime>2020-05-06T06:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T06:00:00+08:00</startTime>
#             <endTime>2020-05-06T12:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T12:00:00+08:00</startTime>
#             <endTime>2020-05-06T18:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T18:00:00+08:00</startTime>
#             <endTime>2020-05-07T00:00:00+08:00</endTime>
#             <elementValue>
#               <value>10</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T00:00:00+08:00</startTime>
#             <endTime>2020-05-07T06:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T06:00:00+08:00</startTime>
#             <endTime>2020-05-07T12:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T12:00:00+08:00</startTime>
#             <endTime>2020-05-07T18:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T18:00:00+08:00</startTime>
#             <endTime>2020-05-08T00:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-08T00:00:00+08:00</startTime>
#             <endTime>2020-05-08T06:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#         </weatherElement>
#         <weatherElement>
#           <elementName>PoP12h</elementName>
#           <description>12小時降雨機率</description>
#           <time>
#             <startTime>2020-05-05T06:00:00+08:00</startTime>
#             <endTime>2020-05-05T18:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-05T18:00:00+08:00</startTime>
#             <endTime>2020-05-06T06:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T06:00:00+08:00</startTime>
#             <endTime>2020-05-06T18:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T18:00:00+08:00</startTime>
#             <endTime>2020-05-07T06:00:00+08:00</endTime>
#             <elementValue>
#               <value>10</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T06:00:00+08:00</startTime>
#             <endTime>2020-05-07T18:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T18:00:00+08:00</startTime>
#             <endTime>2020-05-08T06:00:00+08:00</endTime>
#             <elementValue>
#               <value>0</value>
#               <measures>百分比</measures>
#             </elementValue>
#           </time>
#         </weatherElement>
#         <weatherElement>
#           <elementName>WD</elementName>
#           <description>風向</description>
#           <time>
#             <dataTime>2020-05-05T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏南風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏南風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>西南風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏西風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏西風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>西北風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>西北風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>西北風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>西北風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>西北風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏西風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏西風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏南風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏南風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>西北風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>西北風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏西風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏西風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏西風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏西風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏西風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>東南風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-08T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏南風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-08T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>偏南風</value>
#               <measures>16方位</measures>
#             </elementValue>
#           </time>
#         </weatherElement>
#         <weatherElement>
#           <elementName>WS</elementName>
#           <description>風速</description>
#           <time>
#             <dataTime>2020-05-05T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>4</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>3</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>5</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>3</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>3</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>2</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>3</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>2</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>2</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>&lt;= 1</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>1</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>&lt;= 1</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>2</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>2</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>3</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>2</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>4</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>3</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>5</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>3</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>2</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>2</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>3</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>2</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>2</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>2</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>1</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>&lt;= 1</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>2</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>2</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>3</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>2</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>4</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>3</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>5</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>3</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>3</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>2</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>2</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>2</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>2</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>2</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>2</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>&lt;= 1</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-08T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>2</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>&lt;= 1</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-08T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>2</value>
#               <measures>公尺/秒</measures>
#             </elementValue>
#             <elementValue>
#               <value>2</value>
#               <measures>蒲福風級</measures>
#             </elementValue>
#           </time>
#         </weatherElement>
#         <weatherElement>
#           <elementName>CI</elementName>
#           <description>舒適度指數</description>
#           <time>
#             <dataTime>2020-05-05T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>26</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>27</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>27</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>27</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>27</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>26</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>29</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>27</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>27</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>27</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>26</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>29</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>30</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>29</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-07T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-08T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>28</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-08T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>27</value>
#               <measures>NA</measures>
#             </elementValue>
#             <elementValue>
#               <value>悶熱</value>
#               <measures>自定義 CI 文字</measures>
#             </elementValue>
#           </time>
#         </weatherElement>
#         <weatherElement>
#           <elementName>AT</elementName>
#           <description>體感溫度</description>
#           <time>
#             <dataTime>2020-05-05T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>30</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>31</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>33</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>34</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>33</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-05T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>32</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>32</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>31</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>30</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T09:00:00+08:00</dataTime>
#             <elementValue>
#               <value>32</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T12:00:00+08:00</dataTime>
#             <elementValue>
#               <value>33</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T15:00:00+08:00</dataTime>
#             <elementValue>
#               <value>35</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2020-05-06T18:00:00+08:00</dataTime>
#             <elementValue>
#               <value>33</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
# ...
#             <endTime>2020-05-06T00:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>01</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T00:00:00+08:00</startTime>
#             <endTime>2020-05-06T03:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>01</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T03:00:00+08:00</startTime>
#             <endTime>2020-05-06T06:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>01</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T06:00:00+08:00</startTime>
#             <endTime>2020-05-06T09:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>01</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T09:00:00+08:00</startTime>
#             <endTime>2020-05-06T12:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>01</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T12:00:00+08:00</startTime>
#             <endTime>2020-05-06T15:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>01</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T15:00:00+08:00</startTime>
#             <endTime>2020-05-06T18:00:00+08:00</endTime>
#             <elementValue>
#               <value>多雲</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>04</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T18:00:00+08:00</startTime>
#             <endTime>2020-05-06T21:00:00+08:00</endTime>
#             <elementValue>
#               <value>多雲</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>04</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T21:00:00+08:00</startTime>
#             <endTime>2020-05-07T00:00:00+08:00</endTime>
#             <elementValue>
#               <value>多雲</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>04</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T00:00:00+08:00</startTime>
#             <endTime>2020-05-07T03:00:00+08:00</endTime>
#             <elementValue>
#               <value>多雲</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>04</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T03:00:00+08:00</startTime>
#             <endTime>2020-05-07T06:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>01</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T06:00:00+08:00</startTime>
#             <endTime>2020-05-07T09:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>01</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T09:00:00+08:00</startTime>
#             <endTime>2020-05-07T12:00:00+08:00</endTime>
#             <elementValue>
#               <value>多雲</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>04</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T12:00:00+08:00</startTime>
#             <endTime>2020-05-07T15:00:00+08:00</endTime>
#             <elementValue>
#               <value>午後短暫雷陣雨</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>15</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T15:00:00+08:00</startTime>
#             <endTime>2020-05-07T18:00:00+08:00</endTime>
#             <elementValue>
#               <value>陰</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>07</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T18:00:00+08:00</startTime>
#             <endTime>2020-05-07T21:00:00+08:00</endTime>
#             <elementValue>
#               <value>多雲</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>04</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T21:00:00+08:00</startTime>
#             <endTime>2020-05-08T00:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>01</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-08T00:00:00+08:00</startTime>
#             <endTime>2020-05-08T03:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>01</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-08T03:00:00+08:00</startTime>
#             <endTime>2020-05-08T06:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴</value>
#               <measures>自定義 Wx 文字</measures>
#             </elementValue>
#             <elementValue>
#               <value>01</value>
#               <measures>自定義 Wx 單位</measures>
#             </elementValue>
#           </time>
#         </weatherElement>
#         <weatherElement>
#           <elementName>WeatherDescription</elementName>
#           <description>天氣預報綜合描述</description>
#           <time>
#             <startTime>2020-05-05T06:00:00+08:00</startTime>
#             <endTime>2020-05-05T09:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 0%。溫度攝氏19度。舒適。西南風 平均風速&lt;= 1級(每秒1公尺)。相對濕度81%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-05T09:00:00+08:00</startTime>
#             <endTime>2020-05-05T12:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 0%。溫度攝氏28度。舒適。西南風 平均風速1-2級(每秒2公尺)。相對濕度52%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-05T12:00:00+08:00</startTime>
#             <endTime>2020-05-05T15:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 10%。溫度攝氏32度。悶熱。西南風 平均風速&lt;= 1級(每秒0公尺)。相對濕度45%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-05T15:00:00+08:00</startTime>
#             <endTime>2020-05-05T18:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 10%。溫度攝氏30度。悶熱。西南風 平均風速&lt;= 1級(每秒0公尺)。相對濕度56%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-05T18:00:00+08:00</startTime>
#             <endTime>2020-05-05T21:00:00+08:00</endTime>
#             <elementValue>
#               <value>多雲。降雨機率 10%。溫度攝氏25度。舒適。東南風 平均風速&lt;= 1級(每秒0公尺)。相對濕度73%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-05T21:00:00+08:00</startTime>
#             <endTime>2020-05-06T00:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 10%。溫度攝氏22度。舒適。偏東風 平均風速&lt;= 1級(每秒0公尺)。相對濕度89%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T00:00:00+08:00</startTime>
#             <endTime>2020-05-06T03:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 10%。溫度攝氏21度。舒適。偏東風 平均風速&lt;= 1級(每秒0公尺)。相對濕度88%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T03:00:00+08:00</startTime>
#             <endTime>2020-05-06T06:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 10%。溫度攝氏20度。舒適。偏東風 平均風速&lt;= 1級(每秒0公尺)。相對濕度88%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T06:00:00+08:00</startTime>
#             <endTime>2020-05-06T09:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 0%。溫度攝氏20度。舒適。偏西風 平均風速&lt;= 1級(每秒1公尺)。相對濕度80%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T09:00:00+08:00</startTime>
#             <endTime>2020-05-06T12:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 0%。溫度攝氏28度。舒適。偏西風 平均風速&lt;= 1級(每秒2公尺)。相對濕度53%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T12:00:00+08:00</startTime>
#             <endTime>2020-05-06T15:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 20%。溫度攝氏32度。悶熱。偏西風 平均風速&lt;= 1級(每秒0公尺)。相對濕度41%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T15:00:00+08:00</startTime>
#             <endTime>2020-05-06T18:00:00+08:00</endTime>
#             <elementValue>
#               <value>多雲。降雨機率 20%。溫度攝氏29度。舒適。偏西風 平均風速&lt;= 1級(每秒0公尺)。相對濕度44%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T18:00:00+08:00</startTime>
#             <endTime>2020-05-06T21:00:00+08:00</endTime>
#             <elementValue>
#               <value>多雲。降雨機率 10%。溫度攝氏25度。舒適。東南風 平均風速&lt;= 1級(每秒0公尺)。相對濕度71%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-06T21:00:00+08:00</startTime>
#             <endTime>2020-05-07T00:00:00+08:00</endTime>
#             <elementValue>
#               <value>多雲。降雨機率 10%。溫度攝氏22度。舒適。偏東風 平均風速&lt;= 1級(每秒0公尺)。相對濕度90%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T00:00:00+08:00</startTime>
#             <endTime>2020-05-07T03:00:00+08:00</endTime>
#             <elementValue>
#               <value>多雲。降雨機率 0%。溫度攝氏20度。舒適。偏東風 平均風速&lt;= 1級(每秒0公尺)。相對濕度92%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T03:00:00+08:00</startTime>
#             <endTime>2020-05-07T06:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 0%。溫度攝氏20度。舒適。偏東風 平均風速&lt;= 1級(每秒0公尺)。相對濕度89%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T06:00:00+08:00</startTime>
#             <endTime>2020-05-07T09:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 20%。溫度攝氏19度。舒適。偏西風 平均風速&lt;= 1級(每秒1公尺)。相對濕度82%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T09:00:00+08:00</startTime>
#             <endTime>2020-05-07T12:00:00+08:00</endTime>
#             <elementValue>
#               <value>多雲。降雨機率 20%。溫度攝氏27度。舒適。偏西風 平均風速&lt;= 1級(每秒2公尺)。相對濕度56%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T12:00:00+08:00</startTime>
#             <endTime>2020-05-07T15:00:00+08:00</endTime>
#             <elementValue>
#               <value>午後短暫雷陣雨。降雨機率 90%。溫度攝氏30度。悶熱。偏西風 平均風速&lt;= 1級(每秒0公尺)。相對濕度54%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T15:00:00+08:00</startTime>
#             <endTime>2020-05-07T18:00:00+08:00</endTime>
#             <elementValue>
#               <value>陰。降雨機率 90%。溫度攝氏28度。悶熱。偏西風 平均風速&lt;= 1級(每秒0公尺)。相對濕度73%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T18:00:00+08:00</startTime>
#             <endTime>2020-05-07T21:00:00+08:00</endTime>
#             <elementValue>
#               <value>多雲。降雨機率 0%。溫度攝氏24度。舒適。偏南風 平均風速&lt;= 1級(每秒0公尺)。相對濕度76%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-07T21:00:00+08:00</startTime>
#             <endTime>2020-05-08T00:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 0%。溫度攝氏22度。舒適。偏東風 平均風速&lt;= 1級(每秒0公尺)。相對濕度88%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-08T00:00:00+08:00</startTime>
#             <endTime>2020-05-08T03:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 0%。溫度攝氏21度。舒適。偏東風 平均風速&lt;= 1級(每秒0公尺)。相對濕度89%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#           <time>
#             <startTime>2020-05-08T03:00:00+08:00</startTime>
#             <endTime>2020-05-08T06:00:00+08:00</endTime>
#             <elementValue>
#               <value>晴。降雨機率 0%。溫度攝氏20度。舒適。偏東風 平均風速&lt;= 1級(每秒0公尺)。相對濕度88%。</value>
#               <measures>NA</measures>
#             </elementValue>
#           </time>
#         </weatherElement>
#       </location>
#     </locations>
#   </dataset>
# </cwbopendata>

# %% [markdown]
# ## xmltodict 解析檔案內容

# %%
# 解析檔案內容
import xmltodict
d = dict(xmltodict.parse(xml))  #xml宣告在上個區段

# %%
# 取出 datasetDescription
datasetDescription = d['cwbopendata']['dataset']['datasetInfo']['datasetDescription']
print(datasetDescription)
# Out:
# 臺灣各縣市鄉鎮未來3天(72小時)逐3小時天氣預報

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 請問高雄市有多少地區有溫度資料？
#     2. 請取出每一個地區所記錄的第一個時間點跟溫度
#     3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# 從論壇上看到，擷取下來：
#
# 嗨，根據範例的做法，利用 xmltodict 可以將原本的 xml 轉成 dict 的格式。我們可以先利用網頁打開 .xml 檔案，然後一層一層去找題目所需的地方在哪裡。
# 舉個例子來說，如果我們想要回答的是「請問高雄市有多少地區有溫度資料？」，從原本的 xml 檔案中觀察，可以在「cwbopendata > dataset > locations 」中找到很多個 location ，而每一個 location 代表一個區域。換句話說，題目要問的其實是 cwbopendata > dataset > locations 底下總共有多少個 location。
# 接下來再把上面這個觀察的過程，改成用程式的角度做計算。
#
# ## 解答如下：

# %%
# 1. 請問高雄市有多少地區有溫度資料？

locations = d['cwbopendata']['dataset']['locations']['location']
print(len(locations))
# Out:
# 38

# %%
# Out:
# 鹽埕區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '27'), ('measures', '攝氏度')])
# 鼓山區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '27'), ('measures', '攝氏度')])
# 左營區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '26'), ('measures', '攝氏度')])
# 楠梓區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '26'), ('measures', '攝氏度')])
# 三民區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '27'), ('measures', '攝氏度')])
# 新興區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '27'), ('measures', '攝氏度')])
# 前金區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '27'), ('measures', '攝氏度')])
# 苓雅區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '27'), ('measures', '攝氏度')])
# 前鎮區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '26'), ('measures', '攝氏度')])
# 旗津區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '27'), ('measures', '攝氏度')])
# 小港區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '26'), ('measures', '攝氏度')])
# 鳳山區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '26'), ('measures', '攝氏度')])
# 林園區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '26'), ('measures', '攝氏度')])
# 大寮區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '25'), ('measures', '攝氏度')])
# 大樹區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '24'), ('measures', '攝氏度')])
# 大社區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '25'), ('measures', '攝氏度')])
# 仁武區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '26'), ('measures', '攝氏度')])
# 鳥松區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '25'), ('measures', '攝氏度')])
# 岡山區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '26'), ('measures', '攝氏度')])
# 橋頭區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '25'), ('measures', '攝氏度')])
# 燕巢區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '25'), ('measures', '攝氏度')])
# 田寮區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '24'), ('measures', '攝氏度')])
# 阿蓮區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '25'), ('measures', '攝氏度')])
# 路竹區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '26'), ('measures', '攝氏度')])
# 湖內區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '25'), ('measures', '攝氏度')])
# 茄萣區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '26'), ('measures', '攝氏度')])
# 永安區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '25'), ('measures', '攝氏度')])
# 彌陀區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '25'), ('measures', '攝氏度')])
# 梓官區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '26'), ('measures', '攝氏度')])
# 旗山區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '24'), ('measures', '攝氏度')])
# 美濃區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '24'), ('measures', '攝氏度')])
# 六龜區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '23'), ('measures', '攝氏度')])
# 甲仙區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '22'), ('measures', '攝氏度')])
# 杉林區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '23'), ('measures', '攝氏度')])
# 內門區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '23'), ('measures', '攝氏度')])
# 茂林區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '21'), ('measures', '攝氏度')])
# 桃源區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '20'), ('measures', '攝氏度')])
# 那瑪夏區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '19'), ('measures', '攝氏度')])

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

location = locations[0]
print(location['locationName'])
for l in location['weatherElement'][0]['time']:
    print(l['dataTime'] )
    print(l['elementValue'] )
# Out:
# 鹽埕區
# 2020-05-05T06:00:00+08:00
# OrderedDict([('value', '27'), ('measures', '攝氏度')])
# 2020-05-05T09:00:00+08:00
# OrderedDict([('value', '29'), ('measures', '攝氏度')])
# 2020-05-05T12:00:00+08:00
# OrderedDict([('value', '31'), ('measures', '攝氏度')])
# 2020-05-05T15:00:00+08:00
# OrderedDict([('value', '31'), ('measures', '攝氏度')])
# 2020-05-05T18:00:00+08:00
# OrderedDict([('value', '30'), ('measures', '攝氏度')])
# 2020-05-05T21:00:00+08:00
# OrderedDict([('value', '29'), ('measures', '攝氏度')])
# 2020-05-06T00:00:00+08:00
# OrderedDict([('value', '28'), ('measures', '攝氏度')])
# 2020-05-06T03:00:00+08:00
# OrderedDict([('value', '27'), ('measures', '攝氏度')])
# 2020-05-06T06:00:00+08:00
# OrderedDict([('value', '27'), ('measures', '攝氏度')])
# 2020-05-06T09:00:00+08:00
# OrderedDict([('value', '30'), ('measures', '攝氏度')])
# 2020-05-06T12:00:00+08:00
# OrderedDict([('value', '31'), ('measures', '攝氏度')])
# 2020-05-06T15:00:00+08:00
# OrderedDict([('value', '31'), ('measures', '攝氏度')])
# 2020-05-06T18:00:00+08:00
# OrderedDict([('value', '30'), ('measures', '攝氏度')])
# 2020-05-06T21:00:00+08:00
# OrderedDict([('value', '29'), ('measures', '攝氏度')])
# 2020-05-07T00:00:00+08:00
# OrderedDict([('value', '28'), ('measures', '攝氏度')])
# 2020-05-07T03:00:00+08:00
# OrderedDict([('value', '27'), ('measures', '攝氏度')])
# 2020-05-07T06:00:00+08:00
# OrderedDict([('value', '27'), ('measures', '攝氏度')])
# 2020-05-07T09:00:00+08:00
# OrderedDict([('value', '30'), ('measures', '攝氏度')])
# 2020-05-07T12:00:00+08:00
# OrderedDict([('value', '32'), ('measures', '攝氏度')])
# 2020-05-07T15:00:00+08:00
# OrderedDict([('value', '31'), ('measures', '攝氏度')])
# 2020-05-07T18:00:00+08:00
# OrderedDict([('value', '30'), ('measures', '攝氏度')])
# 2020-05-07T21:00:00+08:00
# OrderedDict([('value', '29'), ('measures', '攝氏度')])
# 2020-05-08T00:00:00+08:00
# OrderedDict([('value', '28'), ('measures', '攝氏度')])
# 2020-05-08T03:00:00+08:00
# OrderedDict([('value', '28'), ('measures', '攝氏度')])
