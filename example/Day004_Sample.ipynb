# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text

#type(r.text)
# Out:
# '[{"id":"12252573049","type":"CreateEvent","actor":{"id":20529101,"login":"jasoncl666","display_login":"jasoncl666","gravatar_id":"","url":"https://api.github.com/users/jasoncl666","avatar_url":"https://avatars.githubusercontent.com/u/20529101?"},"repo":{"id":261642449,"name":"jasoncl666/blog-template","url":"https://api.github.com/repos/jasoncl666/blog-template"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":"gatsby+contentful, creating a headless CMS blog","pusher_type":"user"},"public":true,"created_at":"2020-05-06T03:28:24Z"},{"id":"12252573039","type":"PushEvent","actor":{"id":64879546,"login":"smarch730","display_login":"smarch730","gravatar_id":"","url":"https://api.github.com/users/smarch730","avatar_url":"https://avatars.githubusercontent.com/u/64879546?"},"repo":{"id":261630253,"name":"smarch730/DO101-apps","url":"https://api.github.com/repos/smarch730/DO101-apps"},"payload":{"push_id":5027116560,"size":1,"distinct_size":1,"ref":"refs/
# ...

# %%
import json

json.loads(r.text)

#type(json.loads(r.text))

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)  #params=payloadm用意在於網址後面要帶value，也就是'url': 'http://httpbin.org/get?key1=value1&key2=value2'}
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.18.4',
#   'X-Amzn-Trace-Id': 'Root=1-5eb22ca2-df433d705e9a0f36626dbcbc'},
#  'origin': '123.51.223.4',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})    #data在form項目裡面
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.18.4',
#   'X-Amzn-Trace-Id': 'Root=1-5eb22d77-82acb3082c1f9b481f13d9d8'},
#  'json': None,
#  'origin': '123.51.223.4',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.18.4',
#   'X-Amzn-Trace-Id': 'Root=1-5eb22d3c-6e672278dc749b4765def9b8'},
#  'json': None,
#  'origin': '123.51.223.4',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
